# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#tomar el archivo que voy a subir y meterlo dentro de un dataframe para explorarlo

import pandas as pd
# Change the path to the file you uploaded
df = pd.read_csv('/content/Job Applications.csv')
# Explore the DataFrame
print(df.head())
# Out:
#    Application Date                          Contact Email  \
# 0   4/8/24, 5:47 PM  elganador.inversionista1987@gmail.com
# 1  4/13/24, 8:10 AM  elganador.inversionista1987@gmail.com
# 2  3/12/24, 6:31 PM  elganador.inversionista1987@gmail.com
# 3   4/4/24, 5:00 PM  elganador.inversionista1987@gmail.com
# 4  5/10/24, 6:24 AM  elganador.inversionista1987@gmail.com
#
#   Contact Phone Number               Company Name  \
# 0       +5493764360950  Profile Software Services
# 1       +5493764360950        Implemental Systems
# 2    +54+5493764360950            Axpe Consulting
# 3    +54+5493764360950                  Synechron
# 4       +5493764360950                 Telefónica
#
#                       Job Title                                       Job Url  \
# 0   Data Engineer | 100% remoto  http://www.linkedin.com/jobs/view/3870851747
# 1    Analista de Datos-Power BI  http://www.linkedin.com/jobs/view/3857539400
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Application Date      32 non-null     object
#  1   Contact Email         32 non-null     object
#  2   Contact Phone Number  32 non-null     object
#  3   Company Name          32 non-null     object
#  4   Job Title             32 non-null     object
#  5   Job Url               32 non-null     object
#  6   Resume Name           32 non-null     object
#  7   Question And Answers  29 non-null     object
# dtypes: object(8)
# memory usage: 2.1+ KB

# %%
#  6   Resume Name           32 non-null     object
#  7   Question And Answers  29 non-null     object  borrar estas dos columnas del dataframe

df.drop(['Resume Name', 'Question And Answers'], axis=1, inplace=True)

# %%
# mostrar el dataframe en una tabla

from google.colab import drive
import pandas as pd
drive.mount('/content/drive')

# Change the path to the file you uploaded
df = pd.read_csv('/content/Job Applications.csv')
# Explore the DataFrame
print(df.head())

df.info()

df.drop(['Resume Name', 'Question And Answers'], axis=1, inplace=True)

df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Application Date                          Contact Email  \
# 0   4/8/24, 5:47 PM  elganador.inversionista1987@gmail.com
# 1  4/13/24, 8:10 AM  elganador.inversionista1987@gmail.com
# 2  3/12/24, 6:31 PM  elganador.inversionista1987@gmail.com
# 3   4/4/24, 5:00 PM  elganador.inversionista1987@gmail.com
# 4  5/10/24, 6:24 AM  elganador.inversionista1987@gmail.com
#
#   Contact Phone Number               Company Name  \
# 0       +5493764360950  Profile Software Services
# 1       +5493764360950        Implemental Systems
# 2    +54+5493764360950            Axpe Consulting
# 3    +54+5493764360950                  Synechron
# 4       +5493764360950                 Telefónica
#
#                       Job Title                                       Job Url  \
# 0   Data Engineer | 100% remoto  http://www.linkedin.com/jobs/view/3870851747
# ...

# %%
# eliminar la columna  Contact Email	 y  Contact Phone Number

df.drop(['Contact Email', 'Contact Phone Number'], axis=1, inplace=True)
df
# Out:
#      Application Date                    Company Name  \
# 0     4/8/24, 5:47 PM       Profile Software Services
# 1    4/13/24, 8:10 AM             Implemental Systems
# 2    3/12/24, 6:31 PM                 Axpe Consulting
# 3     4/4/24, 5:00 PM                       Synechron
# 4    5/10/24, 6:24 AM                      Telefónica
# 5     4/5/24, 9:11 AM                        Glocomms
# 6     4/5/24, 9:31 AM                 Grupo PETROPRIX
# 7     4/5/24, 9:43 AM                Mahou San Miguel
# 8    3/19/24, 5:43 AM                           PIXIE
# 9    3/29/24, 4:44 PM               Banco Supervielle
# 10   3/18/24, 2:44 PM                             CGI
# 11    4/5/24, 9:07 AM                           Eugen
# 12    4/9/24, 8:39 AM                  Fervimax Group
# 13  3/16/24, 11:39 AM                         Nextail
# 14   4/11/24, 5:40 PM          Inteligencia Analitica
# 15   5/23/24, 8:32 PM         NTT DATA Europe & Latam
# ...

# %%
#guardar la tabla interactiva en un excel

df.to_excel('/content/drive/MyDrive/Datos-limpios.xlsx', sheet_name='Hoja1')
